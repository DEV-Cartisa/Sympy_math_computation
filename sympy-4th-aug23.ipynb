# %%
import sympy as sym
x = sym.Symbol ('x')
sym.diff( sym.cos(x),x,3)
# Out:
# sin(x)

# %%
x= sym.Symbol ('x')
sym.diff( sym.cos(x),x)
# Out:
# -sin(x)

# %%
#x= sym.Symbol ('x')
#y = sym.Function('y')(x)

#sym.idiff( x**2 + x*y -y**2 + x**3*y**4 - 1 + x**2 ,)

# %%
equation1 = sym.sqrt(x) * sym.tan(x)
x1 = sym.diff(equation1, x)
x1
# Out:
# sqrt(x)*(tan(x)**2 + 1) + tan(x)/(2*sqrt(x))

# %%
equation2 = sym.sqrt(x) * sym.tan(x)
x1 = sym.diff(equation2, x)
x1
# Out:
# sqrt(x)*(tan(x)**2 + 1) + tan(x)/(2*sqrt(x))

# %%
equation3 = 5 / (1 - x)
x1 = sym.diff(equation3, x)
x1
# Out:
# 5/(1 - x)**2

# %%
equation4 = (1 - x) / 5
x1 = sym.diff(equation4, x)
x1
# Out:
# -1/5

# %%
equation5 = sym.sin(2*x) + sym.cos(3*x)
x1 = sym.diff(equation5, x)
x1
# Out:
# -3*sin(3*x) + 2*cos(2*x)

# %%
# Define the variable
theta = sym.symbols('theta')

equation6 = sym.sin(4*theta + sym.pi/2)
x1 = sym.diff(equation6, theta)
x1
# Out:
# -4*sin(4*theta)

# %%
equation7 = sym.tan(theta) + sym.sec(theta)
x1 = sym.diff(equation7, theta)
x1
# Out:
# tan(theta)**2 + tan(theta)*sec(theta) + 1

# %%
equation8 = sym.sin(2*x) * sym.cos(3*x)
s1 = sym.diff(equation8, x)
s1
# Out:
# -3*sin(2*x)*sin(3*x) + 2*cos(2*x)*cos(3*x)

# %%
equation9 = sym.sin(2 * sym.cos(3*x))
z1 = sym.diff(equation9, x)
z1
# Out:
# -6*sin(3*x)*cos(2*cos(3*x))

# %%
equation10 = sym.sec(x)**3 * x**4
x1 = sym.diff(equation10, x)
x1
# Out:
# 3*x**4*tan(x)*sec(x)**3 + 4*x**3*sec(x)**3

# %%
equation9 = sym.sin(2 * sym.cos(3*x))
x1 = sym.diff(equation9, x)
x1
# Out:
# -6*sin(3*x)*cos(2*cos(3*x))

# %%
equation10 = sym.sec(x)**3 * x**4
x1 = sym.diff(equation10, x)
x1
# Out:
# 3*x**4*tan(x)*sec(x)**3 + 4*x**3*sec(x)**3

# %%
equation11 = sym.sqrt(1 - x**2)
x1 = sym.diff(equation11, x)
x1
# Out:
# -x/sqrt(1 - x**2)

# %%
x = sym.Symbol( 'x' )
sym.diff( x**2+x/2 , x ).subs(x,2)
# Out:
# 9/2

# %%
#subs(x,2)

# %%
x = sym.Symbol( 'x' )
sym.solve((x*y**2-x*y-6).subs(x,1))
# Out:
# [{y(1): -2}, {y(1): 3}]

# %%
#in solve, brackets to seperate the function

# %%
x = sym.Symbol('x')
y = sym.Function('y')(x)
sym.idiff(x*y**2-x*y-6,y,x).subs(y,-2).subs(x,1)
# Out:
# 6/5

# %%
x = sym.Symbol('x')
y = sym.Function('y')(x)
sym.idiff(x*y**2-x*y-6,y,x).subs(y,3).subs(x,1)
# Out:
# -6/5

# %%
equation12 = (4*x**2 - 9) * sym.sqrt(4*x**2 + 9)
s1 = sym.diff(equation12, x)
s1
# Out:
# 4*x*(4*x**2 - 9)/sqrt(4*x**2 + 9) + 8*x*sqrt(4*x**2 + 9)

# %%
equation13 = (4*x**2 -9) / (x**2 -16)
s1 = sym.diff(equation13, x)
s1
# Out:
# 8*x/(x**2 - 16) - 2*x*(4*x**2 - 9)/(x**2 - 16)**2

# %%
equation14 = 5*x**(7/2) -2*x**(3/2) +4*x**(-3/2) -8*x**(-5/2)
x1 = sym.diff(equation14, x)
x1
# Out:
# 20.0/x**3.5 - 6.0/x**2.5 - 3.0*x**0.5 + 17.5*x**2.5

# %%
equation15 = sym.exp(x) * sym.ln(x)
x1 = sym.diff(equation14, x)
x1
# Out:
# 20.0/x**3.5 - 6.0/x**2.5 - 3.0*x**0.5 + 17.5*x**2.5

# %%
equation16 = sym.exp(2*x) + sym.ln(x**2 + 1)
x1 = sym.diff(equation16, x )
x1
# Out:
# 2*x/(x**2 + 1) + 2*exp(2*x)

# %%
t = sym.Symbol('t')
equation17 = sym.sin(sym.exp(t)) + sym.cos(sym.exp(t))
x1 = sym.diff(equation17, t)
x1
# Out:
# -exp(t)*sin(exp(t)) + exp(t)*cos(exp(t))

# %%
# error was - add this 
# t = sym.Symbol('t') 
#     t, was not identified

# %%
equation18 = sym.ln(sym.tan(x) + sym.sec(x))
x1 = sym.diff(equation18, x)
x1
# Out:
# (tan(x)**2 + tan(x)*sec(x) + 1)/(tan(x) + sec(x))

# %%
t = sym.Symbol('t')
equation19 = 1/2 * (sym.exp(t) + sym.exp(-t))
x1= sym.diff(equation19, t)
x1
# Out:
# 0.5*exp(t) - 0.5*exp(-t)

# %%
equation20 = sym.atan(3*x - 5)
derivative20 = sym.diff(equation20, x)
derivative20
# Out:
# 3/((3*x - 5)**2 + 1)
